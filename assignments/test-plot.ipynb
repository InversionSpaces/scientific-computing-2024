# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from module import to_cartesian

to_cartesian = np.vectorize(to_cartesian)

# %%
theta = np.linspace(-5 * np.pi, 5 *np.pi, 1000)
r = theta * np.sin(theta)

x, y = to_cartesian(r, theta)

plt.plot(x, y)
